# %%
import pandas as pd
import transformaciones as tf
from ast import literal_eval
from datetime import datetime

data_movies = pd.read_csv('../raw_data/movies_dataset.csv', low_memory=False)
data_credits = pd.read_csv('../raw_data/credits.csv')

# %%
data_movies.dropna(inplace=True)

# %%
data_movies.drop(data_movies[data_movies['vote_average'] <= 5].index, inplace=True)
data_movies.drop(data_movies[data_movies['vote_count'] <= 400].index, inplace=True)

# %%
data_movies.head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 5   False                                                NaN  60000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#                                         homepage     id    imdb_id  \
# 0           http://toystory.disney.com/toy-story    862  tt0114709
# 1                                            NaN   8844  tt0113497
# ...

# %%
data_movies['release_date'] = pd.to_datetime(data_movies['release_date'], errors='coerce')

# %%
len(data_movies[data_movies['release_date'] >= datetime(2013, 1, 1)])
# Out:
# 7910

# %%
len(data_movies[data_movies['vote_average'] >= 6.5])
# Out:
# 16288

# %%
test = data_movies.drop(data_movies[data_movies['vote_average'] >= 6.5].index)

# %%
data_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
data = data_movies.copy()
data.drop_duplicates(inplace=True, subset=['id'])
data['id'] = tf.convertir_entero(data, 'id')
data= data[data.id != 0]
data.dropna(subset=['title', 'production_companies', 'revenue'], inplace=True)
data= data.merge(data_credits, on='id')
data= data[['id', 'title', 'genres', 'overview', 'production_companies', 'cast', 'crew']]

# %%
data['crew'] = data['crew'].apply(lambda x: literal_eval(x))
data['cast'] = data['cast'].apply(lambda x: literal_eval(x))
data['genres'] = data['genres'].apply(lambda x: literal_eval(x))
data['production_companies'] = data['production_companies'].apply(lambda x: literal_eval(x))

# %%
data['crew'] = data['crew'].apply(lambda x: tf.convertir_diccionario(x, data['crew'].name, 'name'))
data['cast'] = data['cast'].apply(lambda x: tf.convertir_diccionario(x, data['cast'].name, 'name'))
data['genres'] = data['genres'].apply(lambda x: tf.convertir_diccionario(x, data['genres'].name, 'name'))
data['production_companies'] = data['production_companies'].apply(lambda x: tf.convertir_diccionario(x, data['production_companies'].name, 'name'))

# %%
data['overview'].fillna(' ', inplace = True)
data['overview'] = data['overview'].apply(lambda x: x.split())

# %%
data['crew'] = data['crew'].apply(lambda x: [i.replace(" ","") for i in x])
data['cast'] = data['cast'].apply(lambda x: [i.replace(" ","") for i in x])
data['genres'] = data['genres'].apply(lambda x: [i.replace(" ","") for i in x])
data['production_companies'] = data['production_companies'].apply(lambda x: [i.replace(" ","") for i in x])

# %%
data['vector'] = data['overview'] + data['genres'] + data['cast'] + data['crew'] + data['production_companies']

data.drop(columns=['overview', 'crew', 'cast', 'genres', 'production_companies'], inplace=True)

# %%
data['vector'] = data['vector'].apply(lambda x: " ".join(x))

# %%
data['vector'] = data['vector'].apply(lambda x: x.lower())

# %%
data.rename(columns={'id': 'movie_id'}, inplace=True)
data.head()
# Out:
#    movie_id                        title  \
# 0       862                    Toy Story
# 1      8844                      Jumanji
# 2     15602             Grumpier Old Men
# 3     31357            Waiting to Exhale
# 4     11862  Father of the Bride Part II
#
#                                               vector
# 0  led by woody, andy's toys live happily in his ...
# 1  when siblings judy and peter discover an encha...
# 2  a family wedding reignites the ancient feud be...
# 3  cheated on, mistreated and stepped on, the wom...
# 4  just when george banks has recovered from his ...

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()
cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
def stem(text):
    lista = list()

    for i in text.split():
        lista.append(ps.stem(i))

    return " ".join(lista)

# %%
data['vector'] = data['vector'].apply(stem)

# %%
import numpy as np

# %%
vectores = cv.fit_transform(data['vector']).toarray().astype(np.float32)

# %%
cercania = cosine_similarity(vectores)
# Out:
# c:\Users\sebas\Documents\Henry_DATA_SCIENCE\PROYECTO INDIVIDUAL\venv\Lib\site-packages\sklearn\utils\extmath.py:189: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
cercania
# Out:
# array([[1.        , 0.08040844, 0.05872202, ..., 0.        , 0.19051939,
#         0.        ],
#        [0.08040844, 1.        , 0.06846532, ..., 0.        , 0.05923488,
#         0.03608439],
#        [0.05872202, 0.06846532, 1.        , ..., 0.        , 0.01622214,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.99999994, 0.        ,
#         0.        ],
#        [0.19051939, 0.05923488, 0.01622214, ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.03608439, 0.        , ..., 0.        , 0.        ,
#         1.        ]], dtype=float32)

# %%
data.head()
# Out:
#    movie_id                        title  \
# 0       862                    Toy Story
# 1      8844                      Jumanji
# 2     15602             Grumpier Old Men
# 3     31357            Waiting to Exhale
# 4     11862  Father of the Bride Part II
#
#                                               vector
# 0  led by woody, andy' toy live happili in hi roo...
# 1  when sibl judi and peter discov an enchant boa...
# 2  a famili wed reignit the ancient feud between ...
# 3  cheat on, mistreat and step on, the women are ...
# 4  just when georg bank ha recov from hi daughter...
